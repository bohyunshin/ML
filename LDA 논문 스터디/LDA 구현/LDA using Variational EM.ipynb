# %%
import pandas as pd
import numpy as np
import timeit

# %%
from math import exp
from scipy.special import gamma
from scipy.special import digamma
from math import log

# %%
# define an empty list
noun_list = []

# open file and read the content in a list
with open('dat.txt', 'r') as filehandle:
    for line in filehandle:
        # remove linebreak which is the last character of the string
        currentPlace = line[:-1]

        # add item to the list
        noun_list.append(currentPlace)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english", max_features=1000)
transformed = cv.fit_transform(noun_list)

# %% [markdown]
# # Latent Dirichlet Allocation in Python

# %% [markdown]
# ## Variational EM
# E-Step: estimate gamma, phi in variational inference <br>
# M-Step: maximize log likelihood w.r.t. alpha and beta

# %% [markdown]
# ### E-Step
# - initiate iteration with initial alpha, beta, gamma and phi
# - for fixed alpha and beta, iteratively update gamma and phi
# - phi corresponds to word probabilities matrix, beta
# - gamma corresponds to dirichlet parameter, alpha
# - E-step is taken by every document

# %% [markdown]
# ### M-Step
# - Fixing the updated gamma and phi in E-Step, update alpha and beta
# - Do E-Step and M-Step until the lower bound converges
# - After finishing E-step for every document, M-step is invoked

# %% [markdown]
# #### Clear the dimension of each parameter
# - K: number of topics (pre-determined before)
# - N: number of total words in 'one' document
# - V: number of unique words in 'one' document
# - alpha, gamma: 1 * K
# - phi: N * K
# - beta: K * V ( topic index * unique words index )

# %%
documents = [["Hadoop", "Big-Data", "HBase", "Java", "Spark", "Storm", "Cassandra"],
    ["NoSQL", "MongoDB", "Cassandra", "HBase", "Postgres"],
    ["Python", "scikit-learn", "scipy", "numpy", "statsmodels", "pandas"],
    ["R", "Python", "statistics", "regression", "probability"],
    ["machine learning", "regression", "decision trees", "libsvm"],
    ["Python", "R", "Java", "C++", "Haskell", "programming languages"],
    ["statistics", "probability", "mathematics", "theory"],
    ["machine learning", "scikit-learn", "Mahout", "neural networks"],
    ["neural networks", "deep-learning", "Big Data", "artificial-intelligence"],
    ["Hadoop", "Java", "MapReduce", "Big Data"],
    ["statistics", "R", "statsmodels"],
    ["C++", "deep-learning", "artificial-intelligence", "probability"],
    ["pandas", "R", "Python"],
    ["databases", "HBase", "Postgres", "MySQL", "MongoDB"],
    ["libsvm", "regression", "support-vector-machines"]]

noun_list = []

for i in range(len(documents)):
    noun_list.append(' '.join(documents[i]))

# %%
# two lists
# 1) unique_words_for_all_docs: consists of all unique words (not index) of all docs from a corpus
# 2) seq_of_words_for_a_doc: consists of all unique words (not index) of nth doc

# the stopwords should be removed before making countvectorizer.
# input of LDA is countvectorizer object, which is  D * V matrix
# where D is the number of documents in a coupus and V is the total unique words.


'''
cv = CountVectorizer(stop_words="english", max_features=1000)
transformed = cv.fit_transform(noun_list)
cv.get_feature_names()
'''

def E_Step(K, alpha, beta, cv, transformed):
    
    # K: number of topics predetermined
    
    from scipy.special import digamma
    from scipy.special import polygamma
    from math import exp
    import numpy as np
    
    V = len(cv.get_feature_names())
    
    D = transformed.shape[0]
    
    # dictionary to put variational parameters in each document
    # the length of dictionary should be equal to D, the number of docs

    phi_corpus_dic = {}
    gamma_corpus_dic = {}
    
    for i in range(D):
        phi_corpus_dic[str(i)] = []
        
        gamma_corpus_dic[str(i)] = []
    
    
    # variational inference on each documnet
    # for each document, we will estimate variational patameters
    
    for d in range(D):
        
        # words list that appear in dth document
        seq_of_words_for_a_doc = [cv.get_feature_names()[i] for i in np.where(transformed.toarray()[d] != 0)[0].tolist()]
        # this returns which words consist of a document
        # for example, for first document, it returns
        # ['경기도', '이과인', '첼시', '콘테']
        # in paper, it corresponds to w_1, w_2, ... ,w_N before converting to unit vector
        
        N = len(seq_of_words_for_a_doc)
        # number of words in dth doc

        t = 0
        
        # initial value for each document
        phi_0 = np.full((N, K), 1/K)  # N * K dimension numpy array
        gamma_0 = alpha + N/K


        while True:
            t += 1
            phi_1 = np.copy(phi_0)
            gamma_1 = np.copy(gamma_0)

            for n in range(N):
                for i in range(K):
                    w_n = cv.get_feature_names().index(seq_of_words_for_a_doc[n])
                    # this returns the index of a word in the vocabulary
                    # for example, the word '경기도' in first document has index '46'
                    
                    # update phi for all n, i (dimension of phi is N * K)
                    phi_1[n,i] = beta[i, w_n] * exp(digamma(gamma_0[i]))
                    # this updates variational parameters phi

                # normalize phi to sum to 1
                phi_1[n,:] = phi_1[n,:] / sum(phi_1[n,:])

            # update gamma
            gamma_1 = alpha + np.sum(phi_1, axis=0)

            diff_phi = np.power(phi_1 - phi_0, np.full((N,K), 2))
            diff_gamma = np.power(gamma_1 - gamma_0, np.full(K, 2))

            if sum(sum(diff_phi)) < 1e-6 and sum(diff_gamma) < 1e-6: 
                break
            else:
                phi_0 = np.copy(phi_1)
                gamma_0 = np.copy(gamma_1)
                
        phi_corpus_dic[str(d)] = phi_1
        gamma_corpus_dic[str(d)] = gamma_1
            
    return phi_corpus_dic, gamma_corpus_dic

# %%
def M_Step(phi_, gamma_, cv, transformed, K):
    
    '''
    The input phi_, gamma_ is dictionary whose lenghts are equal to number of documents in a corpus.
    To access a document in the corpus, phi_['1'] or gamma_['1'] is required because
    the keys of dictionary are consist of str(number)
    
    '''
    
    from scipy.special import digamma
    from scipy.special import polygamma
    from math import exp
    import numpy as np    
    
    
    M = transformed.shape[0]
    V = len(cv.get_feature_names())
    
    alpha_0 = np.full(K, 1/K)  # initial value with alpha
    beta_0  = np.full((K,V), 1/K)  # initial value with beta

    beta_1 = beta_0
    
    ####### beta estimation #######
    
        ####### beta estimation #######
    
    # object to restore value of beta in each iteration
    
    phi_ele = np.full(V,0)
    
    for i in range(K):
        for d in range(M):
            words_indx_per_doc = np.where(transformed.toarray()[d] != 0)[0].tolist()
            temp = beta_1[i,:]
            temp[words_indx_per_doc] = phi_[str(d)][:,i]
            beta_1[i,:] = beta_1[i,:] + temp
            
        # normalize beta to sum to 1
        # note that this normalization is done by summing by row
        # because the ith row of beta means that ith topic in total Kth topics
        beta_1[i,:] = beta_1[i,:] / sum(beta_1[i,:])        
            
    ####### alpha estimation through Newton Rapshon Method using Hessian matrix ####### 
    
    while True:
        
        h_vec = -M * polygamma(1, alpha_0) # K*1 Vector

        z = M * polygamma(1, sum(alpha_0))

        grad_vec = []
        
        # for grad_vec
        for i in range(K):
            # first term
            a = M * ( digamma(sum(alpha_0)) - digamma(alpha_0[i]) )

            # second term
            
            # the summation is over all docs, so for loop is initialized
            
            b = 0
            for d in range(M):
                b += digamma(gamma_[str(d)][i]) - digamma(sum(gamma_[str(d)]))

            grad_vec.append( a+b )

        grad_vec = np.asarray(grad_vec)

        c = sum(grad_vec / h_vec) / (1/z + sum(1/h_vec))

        update_vec = (grad_vec - c) / h_vec
        
        alpha_1 = alpha_0 - update_vec
        
        if sum(np.power(alpha_1 - alpha_0, np.full(K,2))) < 1e-6:
            break
        else:
            alpha_0 = alpha_1
            
    return beta_1, alpha_1

# %%
def ELBO(phi_, gamma_, alpha, beta, cv, transformed,K):
    
    from scipy.special import gamma
    from scipy.special import digamma
    from math import log
    
    ### phi and gamma are dicionary which contain estimation of variational parameters in ecah document
    M = transformed.shape[0]
    V = len(cv.get_feature_names())
    
    log_likelihood_0 = 0
    second = 0
    third = 0
    
    for d in range(M):
        # words list that appear in dth document
        seq_of_words_for_a_doc = [cv.get_feature_names()[i] for i in np.where(transformed.toarray()[d] != 0)[0].tolist()]
        N = len(seq_of_words_for_a_doc)
        
        # first term
        first = log(gamma(sum(alpha))) - sum(np.log(gamma(alpha))) + sum( (alpha-1) * \
        (digamma(gamma_[str(d)]) - digamma(sum(gamma_[str(d)]))) )

        # second term
        for n in range(N):
            second += sum( phi_[str(d)][n,] * (digamma(gamma_[str(d)]) - digamma(sum(gamma_[str(d)]))) )
            
        # third term
        for i in range(K):
            words_indx_per_doc = np.where(transformed.toarray()[d] != 0)[0].tolist()
            third += sum( phi_[str(d)][:,i] * np.log(beta[i,words_indx_per_doc]) )

        fourth = -log(gamma(sum(gamma_[str(d)]))) + sum(np.log(gamma(gamma_[str(d)]))) - \
                sum( (gamma_[str(d)]-1) * (digamma(gamma_[str(d)]) - digamma(sum(gamma_[str(d)]))) )

        fifth = sum( sum(-phi_[str(d)] * np.log(phi_[str(d)])) )

        log_likelihood_0 = log_likelihood_0 + first + second + third + fourth + fifth
        
    return log_likelihood_0

# %%
len(cv.get_feature_names())
# Out:
# 851

# %%
a = 0
while True:
    start = timeit.default_timer()
    a += 1
    if a % 50: print('{0}번째 iteration'.format(a))
    if a == 1: 
        E_result = E_Step(K=5, alpha = np.full(5,1/5), beta = np.full((5, 851), 1/5), cv=cv, transformed=transformed)
        M_result = M_Step(phi_=E_result[0], gamma_=E_result[1], cv=cv, transformed=transformed, K=5)
        log_L_0 = ELBO(phi_=E_result[0], gamma_=E_result[1], alpha=M_result[1], beta=M_result[0], cv=cv, transformed=transformed, K=5)
        continue
        
    else:
        E_result = E_Step(K=5, alpha = M_result[1], beta = M_result[0], cv=cv, transformed=transformed)
        M_result = M_Step(phi_=E_result[0], gamma_=E_result[1], cv=cv, transformed=transformed, K=5)
        log_L_1 = ELBO(phi_=E_result[0], gamma_=E_result[1], alpha=M_result[1], beta=M_result[0], cv=cv, transformed=transformed, K=5)
    
    if (log_L_1 - log_L_0)**2 < 1e-6: break
    else: 
        log_L_0 = log_L_1
        print(log_L_0)
        stop = timeit.default_timer()
        print('Time: ', stop - start)
# Out:
# 1번째 iteration
# 2번째 iteration
# -5913.991311279841
# Time:  0.04251949999888893
# 3번째 iteration
# -5872.779123626017
# Time:  0.043542200000956655
# 4번째 iteration
# -5851.248112054721
# Time:  0.041898499999661
# 5번째 iteration
# -5838.112347471841
# Time:  0.046764700004132465
# 6번째 iteration
# -5829.289762233296
# Time:  0.04770690000441391
# 7번째 iteration
# -5822.965615636187
# Time:  0.04366100000333972
# 8번째 iteration
# -5818.214686714884
# Time:  0.04498059999605175
# 9번째 iteration
# -5814.517078270087
# Time:  0.04683249999652617
# 10번째 iteration
# -5811.558646182246
# Time:  0.04870069999014959
# 11번째 iteration
# -5809.138575414497
# Time:  0.05230450000090059
# 12번째 iteration
# -5807.122593476599
# Time:  0.04455530000268482
# 13번째 iteration
# -5805.417562053797
# Time:  0.04538490000413731
# 14번째 iteration
# -5803.956869826697
# Time:  0.04725709999911487
# 15번째 iteration
# -5802.691629623703
# Time:  0.04981529999349732
# 16번째 iteration
# -5801.585158899153
# Time:  0.047145299991825595
# 17번째 iteration
# -5800.609399681368
# Time:  0.04602220001106616
# 18번째 iteration
# -5799.742527624133
# Time:  0.047781100001884624
# 19번째 iteration
# -5798.967313912763
# Time:  0.04667440000048373
# 20번째 iteration
# -5798.269977467037
# Time:  0.0489503999997396
# 21번째 iteration
# -5797.639364494278
# Time:  0.04821690000244416
# 22번째 iteration
# -5797.066351492549
# Time:  0.04643210000358522
# 23번째 iteration
# -5796.5434038351605
# Time:  0.07929120000335388
# 24번째 iteration
# -5796.064244633329
# Time:  0.07061219999741297
# 25번째 iteration
# -5795.623603039565
# Time:  0.09547509999538306
# 26번째 iteration
# -5795.217020625695
# Time:  0.0642844999965746
# 27번째 iteration
# -5794.84070078731
# Time:  0.05171660000632983
# 28번째 iteration
# -5794.491390435725
# Time:  0.058124100003624335
# 29번째 iteration
# -5794.166286167111
# Time:  0.049642599988146685
# 30번째 iteration
# -5793.862959214279
# Time:  0.05098080000607297
# 31번째 iteration
# -5793.579294932979
# Time:  0.052954200000385754
# 32번째 iteration
# -5793.313443643828
# Time:  0.04982380000001285
# 33번째 iteration
# -inf
# Time:  0.047562300009303726
# 34번째 iteration
# nan
# Time:  0.047303900006227195
# 35번째 iteration
# nan
# Time:  0.05050749999645632
# 36번째 iteration
# nan
# C:\Users\sbh0613\anaconda\lib\site-packages\ipykernel_launcher.py:38: RuntimeWarning: invalid value encountered in double_scalars
# Time:  0.05249309999635443
# 37번째 iteration
# nan
# Time:  0.05593390000285581
# 38번째 iteration
# nan
# Time:  0.06619640000280924
# 39번째 iteration
# nan
# Time:  0.058475899990298785
# 40번째 iteration
# nan
# Time:  0.06015629999455996
# 41번째 iteration
# nan
# Time:  0.04520789999514818
# 42번째 iteration
# nan
# Time:  0.046575500004109927
# 43번째 iteration
# nan
# Time:  0.048775999995996244
# 44번째 iteration
# nan
# Time:  0.04662069999903906
# 45번째 iteration
# nan
# Time:  0.05379879999964032
# 46번째 iteration
# nan
# Time:  0.04995939999935217
# 47번째 iteration
# nan
# Time:  0.054241299993009306
# 48번째 iteration
# nan
# Time:  0.05182500000228174
# 49번째 iteration
# nan
# Time:  0.058741000000736676
# nan
# Time:  0.05778860001009889
# 51번째 iteration
# nan
# Time:  0.04736169999523554
# 52번째 iteration
# nan
# Time:  0.048482600002898835
# 53번째 iteration
# nan
# Time:  0.047135200002230704
# 54번째 iteration
# nan
# Time:  0.05138540000189096
# 55번째 iteration
# nan
# Time:  0.06425330000638496
# 56번째 iteration
# nan
# Time:  0.05019339999125805
# 57번째 iteration
# nan
# Time:  0.04824950000329409
# 58번째 iteration
# nan
# Time:  0.05708650000451598
# 59번째 iteration
# nan
# Time:  0.052010100000188686
# 60번째 iteration
# nan
# Time:  0.04849400000239257
# 61번째 iteration
# nan
# Time:  0.04779110000526998
# 62번째 iteration
# nan
# Time:  0.05009629999403842
# 63번째 iteration
# nan
# Time:  0.057304599991766736
# 64번째 iteration
# nan
# Time:  0.052682100009405985
# 65번째 iteration
# nan
# Time:  0.047765300012542866
# 66번째 iteration
# nan
# Time:  0.04884709999896586
# 67번째 iteration
# nan
# Time:  0.047205299997585826
# 68번째 iteration
# nan
# Time:  0.0525439000048209
# 69번째 iteration
# nan
# Time:  0.04756900000211317
# 70번째 iteration
# nan
# Time:  0.050220599994645454
# 71번째 iteration
# nan
# Time:  0.04874800000106916
# 72번째 iteration
# nan
# Time:  0.05773559999943245
# 73번째 iteration
# nan
# Time:  0.04994260000239592
# 74번째 iteration
# nan
# Time:  0.05144970001128968
# 75번째 iteration
# nan
# Time:  0.04991349999909289
# 76번째 iteration
# nan
# Time:  0.05384829999820795
# 77번째 iteration
# nan
# Time:  0.05935700000554789
# 78번째 iteration
# nan
# Time:  0.0515365000028396
# 79번째 iteration
# nan
# Time:  0.051487999997334555
# 80번째 iteration
# nan
# Time:  0.05075290000240784
# 81번째 iteration
# nan
# Time:  0.05336170000373386
# 82번째 iteration
# nan
# Time:  0.04894100000092294
# 83번째 iteration
# nan
# Time:  0.04782950000662822
# 84번째 iteration
# nan
# Time:  0.04700330000196118
# 85번째 iteration
# nan
# Time:  0.05005659999733325
# 86번째 iteration
# nan
# Time:  0.04960760001267772
# 87번째 iteration
# nan
# Time:  0.04818129999330267
# 88번째 iteration
# nan
# Time:  0.04793259999132715
# 89번째 iteration
# nan
# Time:  0.04831410000042524
# 90번째 iteration
# nan
# Time:  0.05399649999162648
# 91번째 iteration
# nan
# Time:  0.048182400001678616
# 92번째 iteration
# nan
# Time:  0.05007850000401959
# 93번째 iteration
# nan
# Time:  0.0520978999993531
# 94번째 iteration
# nan
# Time:  0.06027640000684187
# 95번째 iteration
# nan
# Time:  0.052102000001468696
# 96번째 iteration
# nan
# Time:  0.04887899999448564
# 97번째 iteration
# nan
# Time:  0.07356160000199452
# 98번째 iteration
# nan
# Time:  0.08032799999637064
# 99번째 iteration
# nan
# Time:  0.08941119999508373
# nan
# Time:  0.06588629999896511
# 101번째 iteration
# nan
# Time:  0.05187619999924209
# 102번째 iteration
# nan
# Time:  0.052138200000626966
# 103번째 iteration
# nan
# Time:  0.05613250000169501
# 104번째 iteration
# nan
# Time:  0.05587129999184981
# 105번째 iteration
# nan
# Time:  0.05269970001245383
# 106번째 iteration
# nan
# Time:  0.05489900000975467
# 107번째 iteration
# nan
# Time:  0.058225800006766804
# 108번째 iteration
# nan
# Time:  0.04935720001230948
# 109번째 iteration
# nan
# Time:  0.047919499993440695
# 110번째 iteration
# nan
# Time:  0.04967649999889545
# 111번째 iteration
# nan
# Time:  0.054144499998074025
# 112번째 iteration
# nan
# Time:  0.04839380001067184
# 113번째 iteration
# nan
# Time:  0.04809600001317449
# 114번째 iteration
# nan
# Time:  0.04960399999981746
# 115번째 iteration
# nan
# Time:  0.0545538000005763
# 116번째 iteration
# nan
# Time:  0.04802740000013728
# 117번째 iteration
# nan
# Time:  0.047568199996021576
# 118번째 iteration
# nan
# Time:  0.05277210001077037
# 119번째 iteration
# nan
# Time:  0.05481649999273941
# 120번째 iteration
# nan
# Time:  0.050899699999717996
# 121번째 iteration
# nan
# Time:  0.04927020000468474
# 122번째 iteration
# nan
# Time:  0.050435299999662675
# 123번째 iteration
# nan
# Time:  0.049649199994746596
# 124번째 iteration
# nan
# Time:  0.052242699995986186
# 125번째 iteration
# nan
# Time:  0.04962379999051336
# 126번째 iteration
# nan
# Time:  0.0484889000072144
# 127번째 iteration
# nan
# Time:  0.05257139999594074
# 128번째 iteration
# nan
# Time:  0.04756339998857584
# 129번째 iteration
# nan
# Time:  0.05222900000808295
# 130번째 iteration
# nan
# Time:  0.04840830000466667
# 131번째 iteration
# nan
# Time:  0.05114070000126958
# 132번째 iteration
# nan
# Time:  0.04913920001126826
# 133번째 iteration
# nan
# Time:  0.055091299989726394
# 134번째 iteration
# nan
# Time:  0.049035800009733066
# 135번째 iteration
# nan
# Time:  0.049312400005874224
# 136번째 iteration
# nan
# Time:  0.04968670000380371
# 137번째 iteration
# nan
# Time:  0.04833969999162946
# 138번째 iteration
# nan
# Time:  0.05576630000723526
# 139번째 iteration
# nan
# Time:  0.0494613000046229
# 140번째 iteration
# nan
# Time:  0.05386400000134017
# 141번째 iteration
# nan
# Time:  0.04850330000044778
# 142번째 iteration
# nan
# Time:  0.050367999996524304
# 143번째 iteration
# nan
# Time:  0.051451699997414835
# 144번째 iteration
# nan
# Time:  0.048320400004740804
# 145번째 iteration
# nan
# Time:  0.048833599998033606
# 146번째 iteration
# nan
# Time:  0.04873039999802131
# 147번째 iteration
# nan
# Time:  0.05665410000074189
# 148번째 iteration
# nan
# Time:  0.05177269999694545
# 149번째 iteration
# nan
# Time:  0.04897630000778008
# nan
# Time:  0.050290699990000576
# 151번째 iteration
# nan
# Time:  0.050280600000405684
# 152번째 iteration
# nan
# Time:  0.06557060001068749
# 153번째 iteration
# nan
# Time:  0.04863439999462571
# 154번째 iteration
# nan
# Time:  0.04952010000124574
# 155번째 iteration
# nan
# Time:  0.04842740000458434
# 156번째 iteration
# nan
# Time:  0.04867550000199117
# 157번째 iteration
# nan
# Time:  0.05440490000182763
# 158번째 iteration
# nan
# Time:  0.05045149999205023
# 159번째 iteration
# nan
# Time:  0.05048289999831468
# 160번째 iteration
# nan
# Time:  0.05596949999744538
# 161번째 iteration
# nan
# Time:  0.051908599998569116
# 162번째 iteration
# nan
# Time:  0.061821399998734705
# 163번째 iteration
# nan
# Time:  0.048122699998202734
# 164번째 iteration
# nan
# Time:  0.0490810000046622
# 165번째 iteration
# C:\Users\sbh0613\anaconda\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\sbh0613\anaconda\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in double_scalars
# nan
# Time:  0.05319370000506751
# 166번째 iteration
# nan
# Time:  0.052259000003687106
# 167번째 iteration
# nan
# Time:  0.05095499999879394
# 168번째 iteration
# nan
# Time:  0.04957550000108313
# 169번째 iteration
# nan
# Time:  0.053268000003299676
# 170번째 iteration
# nan
# Time:  0.05861180000647437
# 171번째 iteration
# nan
# Time:  0.04922919999808073
# 172번째 iteration
# nan
# Time:  0.04990489999181591
# 173번째 iteration
# nan
# Time:  0.05049519999010954
# 174번째 iteration
# nan
# Time:  0.053445400000782683
# 175번째 iteration
# nan
# Time:  0.05177449999609962
# 176번째 iteration
# nan
# Time:  0.04876170000352431
# 177번째 iteration
# nan
# Time:  0.052278400005889125
# 178번째 iteration
# nan
# Time:  0.06218290000106208
# 179번째 iteration
# nan
# Time:  0.05296190000080969
# 180번째 iteration
# nan
# Time:  0.0516811000125017
# 181번째 iteration
# nan
# Time:  0.05162630000268109
# 182번째 iteration
# nan
# Time:  0.04914659999485593
# 183번째 iteration
# nan
# Time:  0.057911399999284185
# 184번째 iteration
# nan
# Time:  0.051576800004113466
# 185번째 iteration
# nan
# Time:  0.04945390000648331
# 186번째 iteration
# nan
# Time:  0.0498300999897765
# 187번째 iteration
# nan
# Time:  0.05167559999972582
# 188번째 iteration
# nan
# Time:  0.05658400000538677
# 189번째 iteration
# nan
# Time:  0.052013199994689785
# 190번째 iteration
# nan
# Time:  0.05402029999822844
# 191번째 iteration
# nan
# Time:  0.05170250000082888
# 192번째 iteration
# nan
# Time:  0.05015629999979865
# 193번째 iteration
# nan
# Time:  0.055189599996083416
# 194번째 iteration
# nan
# Time:  0.05084379999607336
# 195번째 iteration
# nan
# Time:  0.05008770000131335
# 196번째 iteration
# nan
# Time:  0.05096900000353344
# 197번째 iteration
# nan
# Time:  0.050709399991319515
# 198번째 iteration
# nan
# Time:  0.054444499997771345
# 199번째 iteration
# nan
# Time:  0.05024989999947138
# nan
# Time:  0.04868740000529215
# 201번째 iteration
# nan
# Time:  0.04922079999232665
# 202번째 iteration
# nan
# Time:  0.05341670000052545
# 203번째 iteration
# nan
# Time:  0.05108220000693109
# 204번째 iteration
# nan
# Time:  0.048434399999678135
# 205번째 iteration
# nan
# Time:  0.050045100011629984
# 206번째 iteration
# nan
# Time:  0.05264109998825006
# 207번째 iteration
# nan
# Time:  0.060601300006965175
# 208번째 iteration
# nan
# Time:  0.06447700000717305
# 209번째 iteration
# nan
# Time:  0.05654099999810569
# 210번째 iteration
# nan
# Time:  0.05672529998992104
# 211번째 iteration
# nan
# Time:  0.05628180000348948
# 212번째 iteration
# nan
# Time:  0.05540119999204762
# 213번째 iteration
# nan
# Time:  0.05655250001291279
# 214번째 iteration
# nan
# Time:  0.05519620000268333
# 215번째 iteration
# nan
# Time:  0.060178300002007745
# 216번째 iteration
# nan
# Time:  0.058286100000259466
# 217번째 iteration
# nan
# Time:  0.05292560000088997
# 218번째 iteration
# nan
# Time:  0.07152919999498408
# 219번째 iteration
# nan
# Time:  0.08955450000939891
# 220번째 iteration
# nan
# Time:  0.07226040000387002
# 221번째 iteration
# nan
# Time:  0.054284300000290386
# 222번째 iteration
# nan
# Time:  0.04849780000222381
# 223번째 iteration
# nan
# Time:  0.05883190000895411
# 224번째 iteration
# nan
# Time:  0.05137260000628885
# 225번째 iteration
# nan
# Time:  0.04973609998705797
# 226번째 iteration
# nan
# Time:  0.054094299994176254
# 227번째 iteration
# nan
# Time:  0.06484579999232665
# 228번째 iteration
# nan
# Time:  0.0519823000067845
# 229번째 iteration
# nan
# Time:  0.050635200008400716
# 230번째 iteration
# nan
# Time:  0.05104879999998957
# 231번째 iteration
# nan
# Time:  0.052959099994041026
# 232번째 iteration
# nan
# Time:  0.05816220000269823
# 233번째 iteration
# nan
# Time:  0.05066130000341218
# 234번째 iteration
# nan
# Time:  0.05135730000620242
# 235번째 iteration
# nan
# Time:  0.05359300000418443
# 236번째 iteration
# nan
# Time:  0.05384300000150688
# 237번째 iteration
# nan
# Time:  0.055034100005286746
# 238번째 iteration
# nan
# Time:  0.056374899999354966
# 239번째 iteration
# nan
# Time:  0.06070319999707863
# 240번째 iteration
# nan
# Time:  0.056798000005073845
# 241번째 iteration
# nan
# Time:  0.05198489999747835
# 242번째 iteration
# nan
# Time:  0.053599100006977096
# 243번째 iteration
# nan
# Time:  0.056531300011556596
# 244번째 iteration
# nan
# Time:  0.048821699994732626
# 245번째 iteration
# nan
# Time:  0.050730100003420375
# 246번째 iteration
# nan
# Time:  0.05034929999965243
# 247번째 iteration
# nan
# Time:  0.059391600007074885
# 248번째 iteration
# nan
# Time:  0.057105500003672205
# 249번째 iteration
# nan
# Time:  0.06181139999534935
# nan
# Time:  0.05674189999990631
# 251번째 iteration
# nan
# Time:  0.05866670000250451
# 252번째 iteration
# nan
# Time:  0.06449049999355339
# 253번째 iteration
# nan
# Time:  0.06517329999769572
# 254번째 iteration
# nan
# Time:  0.054190199996810406
# 255번째 iteration
# nan
# Time:  0.06088479999743868
# 256번째 iteration
# nan
# Time:  0.0514400999963982
# 257번째 iteration
# nan
# Time:  0.05048059999535326
# 258번째 iteration
# nan
# Time:  0.048746899992693216
# 259번째 iteration
# nan
# Time:  0.05058259998622816
# 260번째 iteration
# nan
# Time:  0.06458020000718534
# 261번째 iteration
# nan
# Time:  0.05476240000280086
# 262번째 iteration
# nan
# Time:  0.04939070000546053
# 263번째 iteration
# nan
# Time:  0.05575509999471251
# 264번째 iteration
# nan
# Time:  0.05639820000214968
# 265번째 iteration
# nan
# Time:  0.06678110000211746
# 266번째 iteration
# nan
# Time:  0.056827899999916553
# 267번째 iteration
# nan
# Time:  0.053133399997022934
# 268번째 iteration
# nan
# Time:  0.05299609999929089
# 269번째 iteration
# nan
# Time:  0.06019360000209417
# 270번째 iteration
# nan
# Time:  0.05661649999092333
# 271번째 iteration
# nan
# Time:  0.05532669999229256
# 272번째 iteration
# nan
# Time:  0.05299079998803791
# 273번째 iteration
# nan
# Time:  0.05426959999022074
# 274번째 iteration
# nan
# Time:  0.050732400006381795
# 275번째 iteration
# nan
# Time:  0.051582799991592765
# 276번째 iteration
# nan
# Time:  0.06912120000924915
# 277번째 iteration
# nan
# Time:  0.06956709999940358
# 278번째 iteration
# nan
# Time:  0.07744519998959731
# 279번째 iteration
# nan
# Time:  0.05467779999889899
# 280번째 iteration
# nan
# Time:  0.0514203000057023
# 281번째 iteration
# nan
# Time:  0.05617700000584591
# 282번째 iteration
# nan
# Time:  0.05778210000426043
# 283번째 iteration
# nan
# Time:  0.07467840000754222
# 284번째 iteration
# nan
# Time:  0.08082100001047365
# 285번째 iteration
# nan
# Time:  0.05822219999390654
# 286번째 iteration
# nan
# Time:  0.05171050000353716
# 287번째 iteration
# nan
# Time:  0.05001589999301359
# 288번째 iteration
# nan
# Time:  0.05207969999173656
# 289번째 iteration
# nan
# Time:  0.05376470000192057
# 290번째 iteration
# nan
# Time:  0.050889999998616986
# 291번째 iteration
# nan
# Time:  0.052047399993170984
# 292번째 iteration
# nan
# Time:  0.057178200004273094
# 293번째 iteration
# nan
# Time:  0.058820400008698925
# 294번째 iteration
# nan
# Time:  0.0587192000093637
# 295번째 iteration
# nan
# Time:  0.05596299999160692
# 296번째 iteration
# nan
# Time:  0.06239629999618046
# 297번째 iteration
# nan
# Time:  0.05557060000137426
# 298번째 iteration
# nan
# Time:  0.05004960000223946
# 299번째 iteration
# nan
# Time:  0.05055429998901673
# nan
# Time:  0.04997339998953976
# 301번째 iteration
# nan
# Time:  0.06046000000787899
# 302번째 iteration
# nan
# Time:  0.06030320000718348
# 303번째 iteration
# nan
# Time:  0.04970600000524428
# 304번째 iteration
# nan
# Time:  0.05720929999370128
# 305번째 iteration
# nan
# Time:  0.052925199997844175
# 306번째 iteration
# nan
# Time:  0.05337140000483487
# 307번째 iteration
# nan
# Time:  0.05489379999926314
# 308번째 iteration
# nan
# Time:  0.04869470000267029
# 309번째 iteration
# nan
# Time:  0.05215290001069661
# 310번째 iteration
# nan
# Time:  0.05117229999450501
# 311번째 iteration
# nan
# Time:  0.052849800005787984
# 312번째 iteration
# nan
# Time:  0.056718699997873046
# 313번째 iteration
# nan
# Time:  0.06812470000295434
# 314번째 iteration
# nan
# Time:  0.05381890000717249
# 315번째 iteration
# nan
# Time:  0.060117400003946386
# 316번째 iteration
# nan
# Time:  0.05557820000103675
# 317번째 iteration
# nan
# Time:  0.0524336999951629
# 318번째 iteration
# nan
# Time:  0.054940300004091114
# 319번째 iteration
# nan
# Time:  0.05007569999725092
# 320번째 iteration
# nan
# Time:  0.05031779999262653
# 321번째 iteration
# nan
# Time:  0.055603300002985634
# 322번째 iteration
# nan
# Time:  0.05443659999582451
# 323번째 iteration
# nan
# Time:  0.055205900003784336
# 324번째 iteration
# nan
# Time:  0.04996600000595208
# 325번째 iteration
# nan
# Time:  0.05109119998815004
# 326번째 iteration
# nan
# Time:  0.05589540000073612
# 327번째 iteration
# nan
# Time:  0.0496595000004163
# 328번째 iteration
# nan
# Time:  0.05284500001289416
# 329번째 iteration
# nan
# Time:  0.057691399997565895
# 330번째 iteration
# nan
# Time:  0.07062470000528265
# 331번째 iteration
# nan
# Time:  0.060766499998862855
# 332번째 iteration
# nan
# Time:  0.08153170000878163
# 333번째 iteration
# nan
# Time:  0.09787820000201464
# 334번째 iteration
# nan
# Time:  0.06355530000291765
# 335번째 iteration
# nan
# Time:  0.05096320000302512
# 336번째 iteration
# nan
# Time:  0.05359899999166373
# 337번째 iteration
# nan
# Time:  0.06487819999165367
# 338번째 iteration
# nan
# Time:  0.06114759999036323
# 339번째 iteration
# nan
# Time:  0.05675550000160001
# 340번째 iteration
# nan
# Time:  0.0638180999958422
# 341번째 iteration
# nan
# Time:  0.0510884000104852
# 342번째 iteration
# nan
# Time:  0.05250850001175422
# 343번째 iteration
# nan
# Time:  0.05101339999237098
# 344번째 iteration
# nan
# Time:  0.050696899998001754
# 345번째 iteration
# nan
# Time:  0.05848399999376852
# 346번째 iteration
# nan
# Time:  0.05273130000568926
# 347번째 iteration
# nan
# Time:  0.051291100011439994
# 348번째 iteration
# nan
# Time:  0.05586089999997057
# 349번째 iteration
# nan
# Time:  0.06273140000121202
# nan
# Time:  0.05196599999908358
# 351번째 iteration
# nan
# Time:  0.05333369999425486
# 352번째 iteration
# nan
# Time:  0.05205549999664072
# 353번째 iteration
# nan
# Time:  0.06390759999339934
# 354번째 iteration
# nan
# Time:  0.059895400001551025
# 355번째 iteration
# nan
# Time:  0.054129800002556294
# 356번째 iteration
# nan
# Time:  0.07345120000536554
# 357번째 iteration
# nan
# Time:  0.055990499997278675
# 358번째 iteration
# nan
# Time:  0.05080539999471512
# 359번째 iteration
# nan
# Time:  0.05235009999887552
# 360번째 iteration
# nan
# Time:  0.052192599992849864
# 361번째 iteration
# nan
# Time:  0.0575403999973787
# 362번째 iteration
# nan
# Time:  0.05321649998950306
# 363번째 iteration
# nan
# Time:  0.05159489999641664
# 364번째 iteration
# nan
# Time:  0.051063400009297766
# 365번째 iteration
# nan
# Time:  0.05372050000005402
# 366번째 iteration
# nan
# Time:  0.061591599995153956
# 367번째 iteration
# nan
# Time:  0.05150629999116063
# 368번째 iteration
# nan
# Time:  0.05259939999086782
# 369번째 iteration
# nan
# Time:  0.05328860000008717
# 370번째 iteration
# nan
# Time:  0.05395660000795033
# 371번째 iteration
# nan
# Time:  0.05142780000460334
# 372번째 iteration
# nan
# Time:  0.05034640000667423
# 373번째 iteration
# nan
# Time:  0.05900760000804439
# 374번째 iteration
# nan
# Time:  0.05138380000425968
# 375번째 iteration
# nan
# Time:  0.05146099999547005
# 376번째 iteration
# nan
# Time:  0.05506119999336079
# 377번째 iteration
# nan
# Time:  0.06454649999795947
# 378번째 iteration
# nan
# Time:  0.05399520001083147
# 379번째 iteration
# nan
# Time:  0.054243100006715395
# 380번째 iteration
# nan
# Time:  0.05584159999853
# 381번째 iteration
# nan
# Time:  0.053526600007899106
# 382번째 iteration
# nan
# Time:  0.05762640001194086
# 383번째 iteration
# nan
# Time:  0.05592169999727048
# 384번째 iteration
# nan
# Time:  0.05516780000471044
# 385번째 iteration
# nan
# Time:  0.06284900000900961
# 386번째 iteration
# nan
# Time:  0.061037100007524714
# 387번째 iteration
# nan
# Time:  0.06456949999846984
# 388번째 iteration
# nan
# Time:  0.09130230000300799
# 389번째 iteration
# nan
# Time:  0.08958320000965614
# 390번째 iteration
# nan
# Time:  0.0771859999949811
# 391번째 iteration
# nan
# Time:  0.05196270000305958
# 392번째 iteration
# nan
# Time:  0.056055599998217076
# 393번째 iteration
# nan
# Time:  0.050986500005819835
# 394번째 iteration
# nan
# Time:  0.05306340000242926
# 395번째 iteration
# nan
# Time:  0.05116170000110287
# 396번째 iteration
# nan
# Time:  0.05631580000044778
# 397번째 iteration
# nan
# Time:  0.0698475000099279
# 398번째 iteration
# nan
# Time:  0.05469469999661669
# 399번째 iteration
# nan
# Time:  0.055373700000927784
# nan
# Time:  0.06188789999578148
# 401번째 iteration
# nan
# Time:  0.05857280000054743
# 402번째 iteration
# nan
# Time:  0.05537159999948926
# 403번째 iteration
# nan
# Time:  0.061348800009000115
# 404번째 iteration
# nan
# Time:  0.0585331999900518
# 405번째 iteration
# nan
# Time:  0.05598790000658482
# 406번째 iteration
# nan
# Time:  0.05904049999662675
# 407번째 iteration
# nan
# Time:  0.06658719999541063
# 408번째 iteration
# nan
# Time:  0.060084999990067445
# 409번째 iteration
# nan
# Time:  0.05745979999483097
# 410번째 iteration
# nan
# Time:  0.05286579999665264
# 411번째 iteration
# nan
# Time:  0.05678729999635834
# 412번째 iteration
# nan
# Time:  0.05821399998967536
# 413번째 iteration
# nan
# Time:  0.061196800001198426
# 414번째 iteration
# nan
# Time:  0.059290000004693866
# 415번째 iteration
# nan
# Time:  0.06649519999336917
# 416번째 iteration
# nan
# Time:  0.05586949999269564
# 417번째 iteration
# nan
# Time:  0.05310289999761153
# 418번째 iteration
# nan
# Time:  0.05258950000279583
# 419번째 iteration
# nan
# Time:  0.05647039999894332
# 420번째 iteration
# nan
# Time:  0.056957900000270456
# 421번째 iteration
# nan
# Time:  0.057725399994524196
# 422번째 iteration
# nan
# Time:  0.055964799990761094
# 423번째 iteration
# nan
# Time:  0.055356299999402836
# 424번째 iteration
# nan
# Time:  0.05449409999710042
# 425번째 iteration
# nan
# Time:  0.05415890000585932
# 426번째 iteration
# nan
# Time:  0.05551089999789838
# 427번째 iteration
# nan
# Time:  0.05743990000337362
# 428번째 iteration
# nan
# Time:  0.0627472000051057
# 429번째 iteration
# nan
# Time:  0.05214709999563638
# 430번째 iteration
# nan
# Time:  0.05435449999640696
# 431번째 iteration
# nan
# Time:  0.05492989999765996
# 432번째 iteration
# nan
# Time:  0.06385530000261497
# 433번째 iteration
# nan
# Time:  0.08691759999783244
# 434번째 iteration
# nan
# Time:  0.06544800000847317
# 435번째 iteration
# nan
# Time:  0.06137719999242108
# 436번째 iteration
# nan
# Time:  0.05935660000250209
# 437번째 iteration
# nan
# Time:  0.06530630000634119
# 438번째 iteration
# nan
# Time:  0.06436940000276081
# 439번째 iteration
# nan
# Time:  0.06536530000448693
# 440번째 iteration
# nan
# Time:  0.05572810000739992
# 441번째 iteration
# nan
# Time:  0.054209900001296774
# 442번째 iteration
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-172-ee398bd14f03> in <module>
#      13         E_result = E_Step(K=5, alpha = M_result[1], beta = M_result[0], cv=cv, transformed=transformed)
#      14         M_result = M_Step(phi_=E_result[0], gamma_=E_result[1], cv=cv, transformed=transformed, K=5)
# ---> 15         log_L_1 = ELBO(phi_=E_result[0], gamma_=E_result[1], alpha=M_result[1], beta=M_result[0], cv=cv, transformed=transformed, K=5)
#      16
#      17     if (log_L_1 - log_L_0)**2 < 1e-6: break
#
# <ipython-input-149-a45c9c15892c> in ELBO(phi_, gamma_, alpha, beta, cv, transformed, K)
#      28         # third term
#      29         for i in range(K):
# ---> 30             words_indx_per_doc = np.where(transformed.toarray()[d] != 0)[0].tolist()
#      31             third += sum( phi_[str(d)][:,i] * np.log(beta[i,words_indx_per_doc]) )
#      32
#
# ~\anaconda\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1033             y = out.T
#    1034         M, N = x._swap(x.shape)
# -> 1035         csr_todense(M, N, x.indptr, x.indices, x.data, y)
#    1036         return out
#    1037
#
# KeyboardInterrupt:
